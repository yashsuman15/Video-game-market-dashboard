# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv(r"E:\coding\CSV\video game\PS4_GamesSales.csv",header=0, encoding='unicode_escape')
df2 = pd.read_csv(r"E:\coding\CSV\video game\XboxOne_GameSales.csv",header=0, encoding='unicode_escape')

# %%
df1
# Out:
#                                     Game    Year             Genre
# 0                     Grand Theft Auto V  2014.0            Action  \
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# 0     Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
df1.dropna(inplace= True)

# %%
list1 = df1["Genre"].unique()
list1.sort(axis=-1)
list1
# Out:
# array(['Action', 'Action-Adventure', 'Adventure', 'Fighting', 'MMO',
#        'Misc', 'Music', 'Party', 'Platform', 'Puzzle', 'Racing',
#        'Role-Playing', 'Shooter', 'Simulation', 'Sports', 'Strategy',
#        'Visual Novel'], dtype=object)

# %%
list2 = df2["Genre"].unique()
list2.sort(axis=-1)
list2
# Out:
# array(['Action', 'Action-Adventure', 'Adventure', 'Fighting', 'MMO',
#        'Misc', 'Music', 'Platform', 'Puzzle', 'Racing', 'Role-Playing',
#        'Shooter', 'Simulation', 'Sports', 'Strategy', 'Visual Novel'],
#       dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 825 entries, 0 to 1030
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           825 non-null    object
#  1   Year           825 non-null    float64
#  2   Genre          825 non-null    object
#  3   Publisher      825 non-null    object
#  4   North America  825 non-null    float64
#  5   Europe         825 non-null    float64
#  6   Japan          825 non-null    float64
#  7   Rest of World  825 non-null    float64
#  8   Global         825 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 64.5+ KB

# %%
df1["Year"].value_counts()
# Out:
# Year
# 2017.0    254
# 2016.0    222
# 2015.0    172
# 2014.0     98
# 2018.0     39
# 2013.0     20
# 2019.0     12
# 2020.0      8
# Name: count, dtype: int64

# %%
df1["Genre"].value_counts()
# Out:
# Genre
# Action              205
# Role-Playing        107
# Shooter              75
# Adventure            71
# Sports               69
# Misc                 55
# Racing               48
# Action-Adventure     38
# Platform             33
# Fighting             32
# Strategy             25
# Simulation           21
# Music                18
# Puzzle               10
# MMO                   8
# Visual Novel          8
# Party                 2
# Name: count, dtype: int64

# %%
df1.sort_values(by=["Year","Global"],ascending=[True,False], inplace=True)

genre_df1 = df1.groupby(["Year"])
# genre_df1.head(50)
genre_df1["Global"].max()
# Out:
# Year
# 2013.0     4.17
# 2014.0    19.39
# 2015.0    15.09
# 2016.0    10.94
# 2017.0    13.40
# 2018.0    13.94
# 2019.0     0.00
# 2020.0     0.00
# Name: Global, dtype: float64

# %%
df1 = df1[(df1["Year"] != 2019) & (df1["Year"] != 2020)]
df1 = df1[(df1["North America"] != 0) & (df1["Europe"] != 0) & (df1["Japan"] != 0) & (df1["Rest of World"] != 0)]

# %%
genre_df1 = df1.groupby(["Year"])
genre_df1["Global"].max()
# Out:
# Year
# 2013.0     4.17
# 2014.0    19.39
# 2015.0    15.09
# 2016.0    10.94
# 2017.0    13.40
# 2018.0    13.94
# Name: Global, dtype: float64

# %%
df1
# Out:
#                                   Game    Year             Genre
# 30                Call of Duty: Ghosts  2013.0           Shooter  \
# 38                       Battlefield 4  2013.0           Shooter
# 43                      FIFA Soccer 14  2013.0            Sports
# 51     Assassin's Creed IV: Black Flag  2013.0  Action-Adventure
# 55               Killzone: Shadow Fall  2013.0           Shooter
# ..                                 ...     ...               ...
# 280  Naruto to Boruto: Shinobi Striker  2018.0            Action
# 289                     Secret of Mana  2018.0      Role-Playing
# 292                      Bravo Team VR  2018.0           Shooter
# 320                 Metal Gear Survive  2018.0            Action
# 323                  Attack on Titan 2  2018.0            Action
#
#                           Publisher  North America  Europe  Japan
# 30                       Activision           1.79    1.64   0.05  \
# ...

# %%
df1.to_csv(r"E:\coding\python module\PS4_gamesales.csv")

# %%
df2.sort_values(by=["Year","Global"],ascending=[True,False], inplace=True)
df2
# Out:
#      Pos                                    Game    Year      Genre
# 21    22                    Call of Duty: Ghosts  2013.0    Shooter  \
# 29    30                      Forza Motorsport 5  2013.0     Racing
# 31    32         Assassin's Creed IV: Black Flag  2013.0     Action
# 34    35                           Battlefield 4  2013.0    Shooter
# 47    48                           Dead Rising 3  2013.0     Action
# ..   ...                                     ...     ...        ...
# 595  596                              De-formers     NaN     Action
# 596  597  Wonder Boy: The Dragon's Trap (Remake)     NaN   Platform
# 597  598     Rock of Ages II: Bigger and Boulder     NaN     Action
# 598  599                                      Fe     NaN     Action
# 602  603                        The Sexy Brutale     NaN  Adventure
#
#              Publisher  North America  Europe  Japan  Rest of World  Global
# ...

# %%
df2.dropna(inplace= True)
df2
# Out:
#      Pos                             Game    Year    Genre
# 21    22             Call of Duty: Ghosts  2013.0  Shooter  \
# 29    30               Forza Motorsport 5  2013.0   Racing
# 31    32  Assassin's Creed IV: Black Flag  2013.0   Action
# 34    35                    Battlefield 4  2013.0  Shooter
# 47    48                    Dead Rising 3  2013.0   Action
# ..   ...                              ...     ...      ...
# 612  613                        Code Vein  2019.0   Action
# 447  448                  Killer Instinct  2020.0     Misc
# 464  465              Whore of the Orient  2020.0     Misc
# 474  475                           Halo 6  2020.0  Shooter
# 482  483          Black Tusk Studios Game  2020.0     Misc
#
#                                   Publisher  North America  Europe  Japan
# 21                               Activision           1.92    0.86   0.00  \
# 29                        Microsoft Studios           1.28    0.90   0.01
# ...

# %%
df2 = df2[(df2["Year"] != 2019) & (df2["Year"] != 2020)]
df2 = df2[(df2["North America"] != 0) & (df2["Europe"] != 0) & (df2["Japan"] != 0) & (df2["Rest of World"] != 0)]

# %%
genre_df2 = df2.groupby(["Year"])
# genre_df2.head(50)
genre_df2["Global"].max()
# Out:
# Year
# 2013.0    2.40
# 2014.0    8.72
# 2015.0    7.37
# 2016.0    5.13
# 2017.0    1.52
# Name: Global, dtype: float64

# %%
df2
# Out:
#      Pos                                  Game    Year             Genre
# 29    30                    Forza Motorsport 5  2013.0            Racing  \
# 47    48                         Dead Rising 3  2013.0            Action
# 0      1                    Grand Theft Auto V  2014.0            Action
# 5      6        Call of Duty: Advanced Warfare  2014.0           Shooter
# 15    16     Halo: The Master Chief Collection  2014.0           Shooter
# 20    21                             Titanfall  2014.0           Shooter
# 45    46                             Far Cry 4  2014.0           Shooter
# 55    56                       Forza Horizon 2  2014.0            Racing
# 58    59        Middle-Earth: Shadow of Mordor  2014.0            Action
# 112  113                  Kinect Sports Rivals  2014.0            Sports
# 1      2             Call of Duty: Black Ops 3  2015.0           Shooter
# 7      8                             Fallout 4  2015.0      Role-Playing
# ...

# %%
df2.to_csv(r"E:\coding\python module\Xbox_gamesales.csv")
